# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import kruskal

from feature_engineering import engineer_features
from utils.load_data import load_data
from data_cleaning import clean_data
from utils.calculate_row_entropy import calculate_row_entropy

# %%
train_df_raw = pd.read_csv("data/train.csv")
test_df_raw = pd.read_csv("data/test.csv")
train_df = load_data("data/train.csv")
train_df = engineer_features(train_df)
test_df = load_data("data/test.csv")
test_df = engineer_features(test_df)

# %%
pd.set_option('display.width', None)          # No width restriction
pd.set_option('display.max_colwidth', None)  # No truncation of column content
pd.set_option('display.max_columns', None)   # Display all columns
pd.set_option('display.max_rows', None)      # Display all rows (if needed)

# %%
# train_df = clean_data(train_df)
# test_df = clean_data(test_df)

# %%
na_info = test_df.isna().sum()[test_df.isna().sum() > 0]
print("test df NA counts")
print(na_info)
# Out:
# test df NA counts
# MSZoning         4
# LotFrontage    227
# Utilities        2
# Exterior1st      1
# Exterior2nd      1
# KitchenQual      1
# Functional       2
# SaleType         1
# dtype: int64

# %%
# MSZoning

# %%
def categorize_lot_area(df):
    # Calculate quintile boundaries using training data
    quintiles = np.quantile(train_df["LotArea"], [0.2, 0.4, 0.6, 0.8])
    
    # Create categories
    conditions = [
        df["LotArea"] <= quintiles[0],
        (df["LotArea"] > quintiles[0]) & (df["LotArea"] <= quintiles[1]),
        (df["LotArea"] > quintiles[1]) & (df["LotArea"] <= quintiles[2]),
        (df["LotArea"] > quintiles[2]) & (df["LotArea"] <= quintiles[3]),
        df["LotArea"] > quintiles[3]
    ]
    
    choices = ["Very Small", "Small", "Medium", "Large", "Very Large"]
    
    return pd.Series(np.select(conditions, choices), index=df.index)

# Apply to both train and test datasets
train_df["LotArea_Cat"] = categorize_lot_area(train_df)
test_df["LotArea_Cat"] = categorize_lot_area(test_df)

# %%
msz_nas = test_df[test_df["MSZoning"].isna()]
msz_nas.transpose()
# Out:
#                             455         756         790         1444
# Id                          1916        2217        2251        2905
# MSSubClass                    30          20          70          20
# MSZoning                     NaN         NaN         NaN         NaN
# LotFrontage                109.0        80.0         NaN       125.0
# LotArea                    21780       14584       56600       31250
# Street                      Grvl        Pave        Pave        Pave
# Alley                         NA          NA          NA          NA
# LotShape                     Reg         Reg         IR1         Reg
# LandContour                  Lvl         Low         Low         Lvl
# Utilities                    NaN      AllPub      AllPub      AllPub
# LotConfig                 Inside      Inside      Inside      Inside
# LandSlope                    Gtl         Mod         Gtl         Gtl
# Neighborhood              IDOTRR      IDOTRR      IDOTRR     Mitchel
# Condition1                  Norm        Norm        Norm      Artery
# Condition2                  Norm        Norm        Norm        Norm
# BldgType                    1Fam        1Fam        1Fam        1Fam
# HouseStyle                1Story      1Story      2.5Unf      1Story
# OverallQual                    2           1           5           1
# OverallCond                    4           5           1           3
# YearBuilt                   1910        1952        1900        1951
# YearRemodAdd                1950        1952        1950        1951
# RoofStyle                  Gable       Gable         Hip       Gable
# RoofMatl                 CompShg     CompShg     CompShg     CompShg
# Exterior1st              Wd Sdng     AsbShng     Wd Sdng      CBlock
# Exterior2nd              Wd Sdng     VinylSd     Wd Sdng     VinylSd
# MasVnrType                  None        None        None        None
# MasVnrArea                   0.0         0.0         0.0         0.0
# ExterQual                     Fa          Fa          TA          TA
# ExterCond                     Fa          Po          TA          Fa
# Foundation                CBlock        Slab      BrkTil      CBlock
# BsmtQual                      NA          NA          TA          NA
# BsmtCond                      NA          NA          TA          NA
# BsmtExposure                  NA          NA          No          NA
# BsmtFinType1                  NA          NA         Unf          NA
# BsmtFinSF1                   0.0         0.0         0.0         0.0
# BsmtFinType2                  NA          NA         Unf          NA
# BsmtFinSF2                   0.0         0.0         0.0         0.0
# BsmtUnfSF                    0.0         0.0       686.0         0.0
# TotalBsmtSF                  0.0         0.0       686.0         0.0
# Heating                     GasA        Wall        GasA        GasA
# HeatingQC                     TA          Po          Ex          TA
# CentralAir                     N           N           Y           Y
# Electrical                 FuseA       FuseA       SBrkr       FuseA
# 1stFlrSF                     810         733        1150        1600
# 2ndFlrSF                       0           0         686           0
# LowQualFinSF                   0           0           0           0
# GrLivArea                    810         733        1836        1600
# BsmtFullBath                 0.0         0.0         0.0         0.0
# BsmtHalfBath                 0.0         0.0         0.0         0.0
# FullBath                       1           1           2           1
# HalfBath                       0           0           0           1
# BedroomAbvGr                   1           2           4           3
# KitchenAbvGr                   1           1           1           1
# KitchenQual                   TA          Fa          TA          TA
# TotRmsAbvGrd                   4           4           7           6
# Functional                  Min1         NaN        Maj1         Mod
# Fireplaces                     0           0           0           0
# FireplaceQu                   NA          NA          NA          NA
# GarageType                Detchd      Attchd      Detchd      Attchd
# GarageYrBlt                 1975        1952        1900        1951
# GarageFinish                 Unf         Unf         Unf         Unf
# GarageCars                   1.0         2.0         1.0         1.0
# GarageArea                 280.0       487.0       288.0       270.0
# GarageQual                    TA          Fa          TA          Fa
# GarageCond                    TA          Po          Fa          TA
# PavedDrive                     N           N           N           N
# WoodDeckSF                   119           0           0           0
# OpenPorchSF                   24           0           0           0
# EnclosedPorch                  0           0           0         135
# 3SsnPorch                      0           0           0           0
# ScreenPorch                    0           0           0           0
# PoolArea                       0           0           0           0
# PoolQC                        NA          NA          NA          NA
# Fence                         NA          NA          NA          NA
# MiscFeature                   NA          NA          NA          NA
# MiscVal                        0           0           0           0
# MoSold                         3           2           1           5
# YrSold                      2009        2008        2008        2006
# SaleType                   ConLD          WD          WD          WD
# SaleCondition             Normal     Abnorml      Normal      Normal
# lot_frontage_missing       False       False        True       False
# has_garage                     1           1           1           1
# has_basement                   0           0           1           0
# LotArea_Cat           Very Large  Very Large  Very Large  Very Large

# %%
# Checking if zoning depends on the neighbourhood
tab_nbhood_vs_mszoning = pd.crosstab(train_df["Neighborhood"], train_df["MSZoning"])

# %%
tab_nbhood_vs_mszoning["row_entropy"] = tab_nbhood_vs_mszoning.apply(calculate_row_entropy, axis=1)
print(tab_nbhood_vs_mszoning)
# Out:
# MSZoning      C (all)  FV  RH   RL  RM  row_entropy
# Neighborhood
# Blmngtn             0   0   0   16   1     0.322757
# Blueste             0   0   0    0   2    -0.000000
# BrDale              0   0   0    0  16    -0.000000
# BrkSide             0   0   0   28  30     0.999142
# ClearCr             0   0   0   28   0    -0.000000
# CollgCr             0   0   0  140  10     0.353359
# Crawfor             0   0   2   46   3     0.557940
# Edwards             0   0   2   90   8     0.541188
# Gilbert             0   0   0   79   0    -0.000000
# IDOTRR              9   0   0    0  28     0.800392
# MeadowV             0   0   0    0  17    -0.000000
# Mitchel             0   0   0   44   5     0.475432
# NAmes               0   0   2  223   0     0.073334
# NPkVill             0   0   0    9   0    -0.000000
# NWAmes              0   0   0   73   0    -0.000000
# NoRidge             0   0   0   41   0    -0.000000
# NridgHt             0   0   0   76   1     0.100001
# OldTown             1   0   0   17  95     0.681921
# SWISU               0   0   5   20   0     0.721928
# Sawyer              0   0   0   72   2     0.179256
# SawyerW             0   0   5   54   0     0.418684
# Somerst             0  65   0   21   0     0.801933
# StoneBr             0   0   0   25   0    -0.000000
# Timber              0   0   0   38   0    -0.000000
# Veenker             0   0   0   11   0    -0.000000

# %%
# Checking if some house types are more common in specific areas
pd.crosstab(train_df["MSSubClass"], train_df["MSZoning"])
# Out:
# MSZoning    C (all)  FV  RH   RL  RM
# MSSubClass
# 20                2  13   3  508  10
# 30                2   0   1   33  33
# 40                0   0   0    2   2
# 45                0   0   1    4   7
# 50                4   0   1   88  51
# 60                0  25   0  273   1
# 70                1   0   3   30  26
# 75                0   0   0    6  10
# 80                0   0   0   58   0
# 85                0   0   0   20   0
# 90                0   0   3   43   6
# 120               0   5   2   59  21
# 160               0  22   0   11  30
# 180               0   0   0    0  10
# 190               1   0   2   16  11

# %%
pd.crosstab(train_df["BldgType"], train_df["MSZoning"])
# Out:
# MSZoning  C (all)  FV  RH    RL   RM
# BldgType
# 1Fam            9  38   9  1025  139
# 2fmCon          1   0   2    16   12
# Duplex          0   0   3    43    6
# Twnhs           0   9   0    10   24
# TwnhsE          0  18   2    57   37

# %%
# Checking whether MSZoning depends on various conditions

# %%
pd.crosstab(train_df["Condition1"], train_df["MSZoning"])
# Out:
# MSZoning    C (all)  FV  RH   RL   RM
# Condition1
# Artery            0   0   1   26   21
# Feedr             2   0   3   65   11
# Norm              8  64  12  997  179
# PosA              0   0   0    8    0
# PosN              0   0   0   19    0
# RRAe              0   0   0    8    3
# RRAn              0   1   0   23    2
# RRNe              0   0   0    2    0
# RRNn              0   0   0    3    2

# %%
tab_bldgtype_vs_mszoning = pd.crosstab(train_df["BldgType"], train_df["MSZoning"])
tab_bldgtype_vs_mszoning["row_entropy"] = tab_bldgtype_vs_mszoning.apply(calculate_row_entropy, axis=1)
tab_bldgtype_vs_mszoning
# Out:
# MSZoning  C (all)  FV  RH    RL   RM  row_entropy
# BldgType
# 1Fam            9  38   9  1025  139     0.828521
# 2fmCon          1   0   2    16   12     1.437437
# Duplex          0   0   3    43    6     0.823631
# Twnhs           0   9   0    10   24     1.431202
# TwnhsE          0  18   2    57   37     1.549704

# %%
summary = pd.DataFrame()
features = ["Neighborhood", "BldgType", "LotArea_Cat", "MSSubClass", "Condition1"]
for feature in features:
    for v in msz_nas[feature].unique():
        summary[f"{feature}_{v}"] = train_df[train_df[feature] == v]["MSZoning"].value_counts(normalize=True, sort=False)

# %%
summary
# Out:
#           Neighborhood_IDOTRR  Neighborhood_Mitchel  BldgType_1Fam  \
# MSZoning
# C (all)              0.243243              0.000000       0.007377
# FV                   0.000000              0.000000       0.031148
# RH                   0.000000              0.000000       0.007377
# RL                   0.000000              0.897959       0.840164
# RM                   0.756757              0.102041       0.113934
#
#           LotArea_Cat_Very Large  MSSubClass_30  MSSubClass_20  MSSubClass_70  \
# MSZoning
# C (all)                 0.003425       0.028986       0.003731       0.016667
# FV                      0.003425       0.000000       0.024254       0.000000
# RH                      0.000000       0.014493       0.005597       0.050000
# RL                      0.962329       0.478261       0.947761       0.500000
# RM                      0.030822       0.478261       0.018657       0.433333
#
#           Condition1_Norm  Condition1_Artery
# MSZoning
# C (all)          0.006349           0.000000
# FV               0.050794           0.000000
# RH               0.009524           0.020833
# RL               0.791270           0.541667
# RM               0.142063           0.437500

# %%
results = []

# %%
for idx,row in msz_nas.iterrows():
    df = pd.DataFrame({"Id": [row["Id"]]})
    for feature in features:
        summ_col = f"{feature}_{row[feature]}"
        df[feature] = row[feature]
        df[f"{feature}_pred"] = summary[summ_col].idxmax()
        df[f"{feature}_prob"] = summary[summ_col].max()
    results.append(df)
    
results = pd.concat(results, ignore_index=True)

# %%
results = results.set_index("Id")

# %%
results
# Out:
#      Neighborhood Neighborhood_pred  Neighborhood_prob BldgType BldgType_pred  \
# Id
# 1916       IDOTRR                RM           0.756757     1Fam            RL
# 2217       IDOTRR                RM           0.756757     1Fam            RL
# 2251       IDOTRR                RM           0.756757     1Fam            RL
# 2905      Mitchel                RL           0.897959     1Fam            RL
#
#       BldgType_prob LotArea_Cat LotArea_Cat_pred  LotArea_Cat_prob  \
# Id
# 1916       0.840164  Very Large               RL          0.962329
# 2217       0.840164  Very Large               RL          0.962329
# 2251       0.840164  Very Large               RL          0.962329
# 2905       0.840164  Very Large               RL          0.962329
#
#       MSSubClass MSSubClass_pred  MSSubClass_prob Condition1 Condition1_pred  \
# Id
# 1916          30              RL         0.478261       Norm              RL
# 2217          20              RL         0.947761       Norm              RL
# 2251          70              RL         0.500000       Norm              RL
# 2905          20              RL         0.947761     Artery              RL
#
#       Condition1_prob
# Id
# 1916         0.791270
# 2217         0.791270
# 2251         0.791270
# 2905         0.541667

# %%
# I was unable to fit CatBoost and RF and any model, because MSZoning has severe class imbalance
# So I've just calculated conditional probabilities and used "Neighborhood", "BldgType", "LotArea_Cat", "MSSubClass", "Condition1" features for it
# I believe Neighborhood is main predictor of zone type, so I will use neighborhood based predictions for the missing data, except Id=2217, where MSSubClass-based MSZoning probability is ~95% RL

# %%
# summary.to_string("summary.txt")
