# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from data_consistency_check import check_data_consistency
from feature_engineering import engineer_features
from utils.load_data import load_data
from data_cleaning import clean_data

# %%
train_df_raw = pd.read_csv("data/train.csv")
test_df_raw = pd.read_csv("data/test.csv")
train_df = load_data("data/train.csv")
train_df = engineer_features(train_df)
test_df = load_data("data/test.csv")
test_df = engineer_features(test_df)

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)

# %%
# Checking data consistency after initial cleaning
train_df_check = check_data_consistency(train_df)
test_df_check = check_data_consistency(test_df)

# %%
# checking masonry veneer data consistency
print(sum(~train_df_check["mas_vnr_consistent"]))
# 7
# Out:
# 7

# %%
print(sum(~test_df_check["mas_vnr_consistent"]))
# 4
# Out:
# 4

# %%
train_df[~train_df["mas_vnr_consistent"]].transpose()
# Out:
#                                         624      688      773      1230  \
# Id                                       625      689      774     1231
# MSSubClass                                60       20       20       90
# MSZoning                                  RL       RL       RL       RL
# LotFrontage                             80.0     60.0     70.0      NaN
# LotArea                                10400     8089    10150    18890
# Street                                  Pave     Pave     Pave     Pave
# Alley                                     NA       NA       NA       NA
# LotShape                                 Reg      Reg      Reg      IR1
# LandContour                              Lvl      HLS      Lvl      Lvl
# Utilities                             AllPub   AllPub   AllPub   AllPub
# LotConfig                             Inside   Inside   Inside   Inside
# LandSlope                                Gtl      Gtl      Gtl      Gtl
# Neighborhood                          NWAmes  StoneBr    NAmes   Sawyer
# Condition1                              Norm     Norm    Feedr    Feedr
# Condition2                              Norm     Norm     Norm     RRAe
# BldgType                                1Fam     1Fam     1Fam   Duplex
# HouseStyle                            2Story   1Story   1Story   1.5Fin
# OverallQual                                6        8        5        5
# OverallCond                                5        6        5        5
# YearBuilt                               1972     2007     1958     1977
# YearRemodAdd                            1972     2007     1958     1977
# RoofStyle                              Gable    Gable    Gable     Shed
# RoofMatl                             CompShg  CompShg  CompShg  CompShg
# Exterior1st                          VinylSd  MetalSd  Wd Sdng  Plywood
# Exterior2nd                          VinylSd  MetalSd  Wd Sdng  Plywood
# MasVnrType                              None  BrkFace     None     None
# MasVnrArea                             288.0      0.0      1.0      1.0
# ExterQual                                 TA       Gd       TA       TA
# ExterCond                                 TA       TA       TA       TA
# Foundation                            CBlock    PConc   CBlock   CBlock
# BsmtQual                                  TA       Gd       TA       Gd
# BsmtCond                                  TA       TA       TA       TA
# BsmtExposure                              No       Av       No       No
# BsmtFinType1                             Rec      GLQ      Rec      GLQ
# BsmtFinSF1                               247      945      456      498
# BsmtFinType2                             Unf      Unf      Unf      Rec
# BsmtFinSF2                                 0        0        0      211
# BsmtUnfSF                                485      474      456      652
# TotalBsmtSF                              732     1419      912     1361
# Heating                                 GasA     GasA     GasA     GasA
# HeatingQC                                 Gd       Ex       Ex       Ex
# CentralAir                                 Y        Y        Y        Y
# Electrical                             SBrkr    SBrkr    FuseA    SBrkr
# 1stFlrSF                                1012     1419      912     1361
# 2ndFlrSF                                 778        0        0     1259
# LowQualFinSF                               0        0        0        0
# GrLivArea                               1790     1419      912     2620
# BsmtFullBath                               1        1        0        0
# BsmtHalfBath                               0        0        0        0
# FullBath                                   1        2        1        2
# HalfBath                                   2        0        0        2
# BedroomAbvGr                               4        2        2        4
# KitchenAbvGr                               1        1        1        2
# KitchenQual                               TA       Gd       TA       TA
# TotRmsAbvGrd                               8        7        5       12
# Functional                              Min2      Typ      Typ      Typ
# Fireplaces                                 1        1        0        1
# FireplaceQu                               TA       Gd       NA       TA
# GarageType                            Attchd   Attchd   Attchd  BuiltIn
# GarageYrBlt                             1972     2007     1958     1977
# GarageFinish                             RFn      RFn      RFn      RFn
# GarageCars                                 2        2        1        2
# GarageArea                               484      567      275      600
# GarageQual                                TA       TA       TA       TA
# GarageCond                                TA       TA       TA       TA
# PavedDrive                                 Y        Y        Y        N
# WoodDeckSF                               148      140        0      155
# OpenPorchSF                                0        0        0       24
# EnclosedPorch                              0        0        0      145
# 3SsnPorch                                  0        0        0        0
# ScreenPorch                              147        0        0        0
# PoolArea                                   0        0        0        0
# PoolQC                                    NA       NA       NA       NA
# Fence                                     NA       NA       NA       NA
# MiscFeature                               NA       NA       NA     Gar2
# MiscVal                                    0        0        0     8300
# MoSold                                    11       10        7        8
# YrSold                                  2006     2007     2007     2007
# SaleType                                  WD      New      COD       WD
# SaleCondition                         Normal  Partial   Normal   Normal
# SalePrice                             165150   392000   114500   190000
# lot_frontage_missing                   False    False    False     True
# has_garage                                 1        1        1        1
# has_basement                               1        1        1        1
# garage_type_consistent                  True     True     True     True
# garage_features_consistent              True     True     True     True
# garage_area_reasonable                  True     True     True     True
# basement_features_consistent            True     True     True     True
# has_consistent_second_finished_area     True     True     True     True
# basement_areas_match                    True     True     True     True
# mas_vnr_consistent                     False    False    False    False
#
#                                         1241     1300     1334
# Id                                      1242     1301     1335
# MSSubClass                                20       60      160
# MSZoning                                  RL       RL       RM
# LotFrontage                             83.0      NaN     24.0
# LotArea                                 9849    10762     2368
# Street                                  Pave     Pave     Pave
# Alley                                     NA       NA       NA
# LotShape                                 Reg      IR1      Reg
# LandContour                              Lvl      Lvl      Lvl
# Utilities                             AllPub   AllPub   AllPub
# LotConfig                             Inside  CulDSac   Inside
# LandSlope                                Gtl      Gtl      Gtl
# Neighborhood                         Somerst  Gilbert   BrDale
# Condition1                              Norm     Norm     Norm
# Condition2                              Norm     Norm     Norm
# BldgType                                1Fam     1Fam   TwnhsE
# HouseStyle                            1Story   2Story   2Story
# OverallQual                                7        7        5
# OverallCond                                6        5        6
# YearBuilt                               2007     1999     1970
# YearRemodAdd                            2007     1999     1970
# RoofStyle                                Hip    Gable    Gable
# RoofMatl                             CompShg  CompShg  CompShg
# Exterior1st                          VinylSd  VinylSd  HdBoard
# Exterior2nd                          VinylSd  VinylSd  HdBoard
# MasVnrType                             Stone     None     None
# MasVnrArea                               0.0    344.0    312.0
# ExterQual                                 Gd       Gd       TA
# ExterCond                                 TA       TA       TA
# Foundation                             PConc    PConc   CBlock
# BsmtQual                                  Gd       Gd       TA
# BsmtCond                                  TA       TA       TA
# BsmtExposure                              Av       No       No
# BsmtFinType1                             Unf      GLQ      LwQ
# BsmtFinSF1                                 0      694      765
# BsmtFinType2                             Unf      Unf      Unf
# BsmtFinSF2                                 0        0        0
# BsmtUnfSF                               1689      284        0
# TotalBsmtSF                             1689      978      765
# Heating                                 GasA     GasA     GasA
# HeatingQC                                 Ex       Ex       TA
# CentralAir                                 Y        Y        Y
# Electrical                             SBrkr    SBrkr    SBrkr
# 1stFlrSF                                1689     1005      765
# 2ndFlrSF                                   0      978      600
# LowQualFinSF                               0        0        0
# GrLivArea                               1689     1983     1365
# BsmtFullBath                               0        0        0
# BsmtHalfBath                               0        0        0
# FullBath                                   2        2        1
# HalfBath                                   0        1        1
# BedroomAbvGr                               3        3        3
# KitchenAbvGr                               1        1        1
# KitchenQual                               Gd       Gd       TA
# TotRmsAbvGrd                               7        9        7
# Functional                               Typ      Typ     Min1
# Fireplaces                                 0        1        0
# FireplaceQu                               NA       TA       NA
# GarageType                            Attchd   Attchd   Attchd
# GarageYrBlt                             2007     1999     1970
# GarageFinish                             RFn      Fin      Unf
# GarageCars                                 3        2        2
# GarageArea                               954      490      440
# GarageQual                                TA       TA       TA
# GarageCond                                TA       TA       TA
# PavedDrive                                 Y        Y        Y
# WoodDeckSF                                 0        0        0
# OpenPorchSF                               56        0       36
# EnclosedPorch                              0        0        0
# 3SsnPorch                                  0        0        0
# ScreenPorch                                0        0        0
# PoolArea                                   0        0        0
# PoolQC                                    NA       NA       NA
# Fence                                     NA       NA       NA
# MiscFeature                               NA       NA       NA
# MiscVal                                    0        0        0
# MoSold                                     6        5        5
# YrSold                                  2007     2009     2009
# SaleType                                 New       WD       WD
# SaleCondition                        Partial   Normal   Normal
# SalePrice                             248328   225000   125000
# lot_frontage_missing                   False     True    False
# has_garage                                 1        1        1
# has_basement                               1        1        1
# garage_type_consistent                  True     True     True
# garage_features_consistent              True     True     True
# garage_area_reasonable                  True     True     True
# basement_features_consistent            True     True     True
# has_consistent_second_finished_area     True     True     True
# basement_areas_match                    True     True     True
# mas_vnr_consistent                     False    False    False

# %%
train_df[train_df["MasVnrArea"] > 0]["MasVnrType"].value_counts()
# Out:
# MasVnrType
# BrkFace    444
# Stone      127
# BrkCmn      15
# None         5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))  # Make plot larger for better readability

# Create histogram with specific improvements
sns.histplot(
    data=train_df[train_df["MasVnrType"].astype(str) != "None"],
    x="MasVnrArea",
    binwidth=50,  # Set specific bin width for better granularity
    stat="count",  # Show actual counts
)

# Add title and labels
plt.title("Distribution of Masonry Veneer Area (Non-None Types)")
plt.xlabel("Masonry Veneer Area (sq ft)")
plt.ylabel("Number of Houses")

# Add grid for better readability
plt.grid(True, alpha=0.3)

# Focus on the zero area by adding a text annotation
zero_count = len(
    train_df[
        (train_df["MasVnrType"].astype(str) != "None") & (train_df["MasVnrArea"] == 0)
    ]
)
plt.text(50, plt.gca().get_ylim()[1] * 0.95, f"Houses with zero area: {zero_count}")

plt.show()

# %%
train_df[train_df["MasVnrArea"] < 10]["MasVnrArea"].unique()
# Out:
# array([0., 1.], dtype=float32)

# %%
test_df[test_df["MasVnrArea"] < 10]["MasVnrArea"].unique()
# Out:
# array([0., 3., 1.], dtype=float32)

# %%
ids = train_df[~train_df["mas_vnr_consistent"]]["Id"].values
train_df_raw[train_df_raw["Id"].isin(ids)].transpose()
# Out:
#                   624      688      773      1230     1241     1300     1334
# Id                 625      689      774     1231     1242     1301     1335
# MSSubClass          60       20       20       90       20       60      160
# MSZoning            RL       RL       RL       RL       RL       RL       RM
# LotFrontage       80.0     60.0     70.0      NaN     83.0      NaN     24.0
# LotArea          10400     8089    10150    18890     9849    10762     2368
# Street            Pave     Pave     Pave     Pave     Pave     Pave     Pave
# Alley              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# LotShape           Reg      Reg      Reg      IR1      Reg      IR1      Reg
# LandContour        Lvl      HLS      Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside   Inside   Inside   Inside   Inside  CulDSac   Inside
# LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood    NWAmes  StoneBr    NAmes   Sawyer  Somerst  Gilbert   BrDale
# Condition1        Norm     Norm    Feedr    Feedr     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     RRAe     Norm     Norm     Norm
# BldgType          1Fam     1Fam     1Fam   Duplex     1Fam     1Fam   TwnhsE
# HouseStyle      2Story   1Story   1Story   1.5Fin   1Story   2Story   2Story
# OverallQual          6        8        5        5        7        7        5
# OverallCond          5        6        5        5        6        5        6
# YearBuilt         1972     2007     1958     1977     2007     1999     1970
# YearRemodAdd      1972     2007     1958     1977     2007     1999     1970
# RoofStyle        Gable    Gable    Gable     Shed      Hip    Gable    Gable
# RoofMatl       CompShg  CompShg  CompShg  CompShg  CompShg  CompShg  CompShg
# Exterior1st    VinylSd  MetalSd  Wd Sdng  Plywood  VinylSd  VinylSd  HdBoard
# Exterior2nd    VinylSd  MetalSd  Wd Sdng  Plywood  VinylSd  VinylSd  HdBoard
# MasVnrType         NaN  BrkFace      NaN      NaN    Stone      NaN      NaN
# MasVnrArea       288.0      0.0      1.0      1.0      0.0    344.0    312.0
# ExterQual           TA       Gd       TA       TA       Gd       Gd       TA
# ExterCond           TA       TA       TA       TA       TA       TA       TA
# Foundation      CBlock    PConc   CBlock   CBlock    PConc    PConc   CBlock
# BsmtQual            TA       Gd       TA       Gd       Gd       Gd       TA
# BsmtCond            TA       TA       TA       TA       TA       TA       TA
# BsmtExposure        No       Av       No       No       Av       No       No
# BsmtFinType1       Rec      GLQ      Rec      GLQ      Unf      GLQ      LwQ
# BsmtFinSF1         247      945      456      498        0      694      765
# BsmtFinType2       Unf      Unf      Unf      Rec      Unf      Unf      Unf
# BsmtFinSF2           0        0        0      211        0        0        0
# BsmtUnfSF          485      474      456      652     1689      284        0
# TotalBsmtSF        732     1419      912     1361     1689      978      765
# Heating           GasA     GasA     GasA     GasA     GasA     GasA     GasA
# HeatingQC           Gd       Ex       Ex       Ex       Ex       Ex       TA
# CentralAir           Y        Y        Y        Y        Y        Y        Y
# Electrical       SBrkr    SBrkr    FuseA    SBrkr    SBrkr    SBrkr    SBrkr
# 1stFlrSF          1012     1419      912     1361     1689     1005      765
# 2ndFlrSF           778        0        0     1259        0      978      600
# LowQualFinSF         0        0        0        0        0        0        0
# GrLivArea         1790     1419      912     2620     1689     1983     1365
# BsmtFullBath         1        1        0        0        0        0        0
# BsmtHalfBath         0        0        0        0        0        0        0
# FullBath             1        2        1        2        2        2        1
# HalfBath             2        0        0        2        0        1        1
# BedroomAbvGr         4        2        2        4        3        3        3
# KitchenAbvGr         1        1        1        2        1        1        1
# KitchenQual         TA       Gd       TA       TA       Gd       Gd       TA
# TotRmsAbvGrd         8        7        5       12        7        9        7
# Functional        Min2      Typ      Typ      Typ      Typ      Typ     Min1
# Fireplaces           1        1        0        1        0        1        0
# FireplaceQu         TA       Gd      NaN       TA      NaN       TA      NaN
# GarageType      Attchd   Attchd   Attchd  BuiltIn   Attchd   Attchd   Attchd
# GarageYrBlt     1972.0   2007.0   1958.0   1977.0   2007.0   1999.0   1970.0
# GarageFinish       RFn      RFn      RFn      RFn      RFn      Fin      Unf
# GarageCars           2        2        1        2        3        2        2
# GarageArea         484      567      275      600      954      490      440
# GarageQual          TA       TA       TA       TA       TA       TA       TA
# GarageCond          TA       TA       TA       TA       TA       TA       TA
# PavedDrive           Y        Y        Y        N        Y        Y        Y
# WoodDeckSF         148      140        0      155        0        0        0
# OpenPorchSF          0        0        0       24       56        0       36
# EnclosedPorch        0        0        0      145        0        0        0
# 3SsnPorch            0        0        0        0        0        0        0
# ScreenPorch        147        0        0        0        0        0        0
# PoolArea             0        0        0        0        0        0        0
# PoolQC             NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Fence              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# MiscFeature        NaN      NaN      NaN     Gar2      NaN      NaN      NaN
# MiscVal              0        0        0     8300        0        0        0
# MoSold              11       10        7        8        6        5        5
# YrSold            2006     2007     2007     2007     2007     2009     2009
# SaleType            WD      New      COD       WD      New       WD       WD
# SaleCondition   Normal  Partial   Normal   Normal  Partial   Normal   Normal
# SalePrice       165150   392000   114500   190000   248328   225000   125000

# %%
train_df = clean_data(train_df)
test_df = clean_data(test_df)
train_df_check = check_data_consistency(train_df)
test_df_check = check_data_consistency(test_df)

# %%
# checking masonry veneer data consistency
print(sum(~train_df_check["mas_vnr_consistent"]))
# 7
# Out:
# 0

# %%
print(sum(~test_df_check["mas_vnr_consistent"]))
# 4
# Out:
# 0
